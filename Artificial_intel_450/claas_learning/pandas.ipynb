# %%
import numpy as np
import pandas as pd

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df=pd.read_csv('covid_toy.csv')

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %%
df.shape
# Out:
# (100, 6)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
df = df.fillna(0)

# %%
cat_col=df.columns[df.dtypes=="object"]
num_cols=df.columns[df.dtypes!="object"]

# %%
df[num_cols]
# Out:
#     age  fever
# 0    60  103.0
# 1    27  100.0
# 2    42  101.0
# 3    31   98.0
# 4    65  101.0
# ..  ...    ...
# 95   12  104.0
# 96   51  101.0
# 97   20  101.0
# 98    5   98.0
# 99   10   98.0
#
# [100 rows x 2 columns]

# %%
df[cat_col]
# Out:
#     gender   cough       city has_covid
# 0     Male    Mild    Kolkata        No
# 1     Male    Mild      Delhi       Yes
# 2     Male    Mild      Delhi        No
# 3   Female    Mild    Kolkata        No
# 4   Female    Mild     Mumbai        No
# ..     ...     ...        ...       ...
# 95  Female    Mild  Bangalore        No
# 96  Female  Strong    Kolkata       Yes
# 97  Female    Mild  Bangalore        No
# 98  Female  Strong     Mumbai        No
# 99  Female  Strong    Kolkata       Yes
#
# [100 rows x 4 columns]

# %%
df[num_cols].describe()
# Out:
#               age       fever
# count  100.000000  100.000000
# mean    44.220000   90.760000
# std     24.878931   30.468106
# min      5.000000    0.000000
# 25%     20.000000   98.000000
# 50%     45.000000  100.500000
# 75%     66.500000  102.000000
# max     84.000000  104.000000

# %%
# !pip install seaborn
# !pip install matplotlib

import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from seaborn) (2.2.3)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.55.8-cp312-cp312-win_amd64.whl.metadata (103 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pillow-11.1.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.8-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 258.0 kB/s eta 0:00:07
#    --------- ------------------------------ 0.5/2.2 MB 258.0 kB/s eta 0:00:07
#    --------- ------------------------------ 0.5/2.2 MB 258.0 kB/s eta 0:00:07
#    --------- ------------------------------ 0.5/2.2 MB 258.0 kB/s eta 0:00:07
#    -------------- ------------------------- 0.8/2.2 MB 279.6 kB/s eta 0:00:06
#    -------------- ------------------------- 0.8/2.2 MB 279.6 kB/s eta 0:00:06
#    -------------- ------------------------- 0.8/2.2 MB 279.6 kB/s eta 0:00:06
#    -------------- ------------------------- 0.8/2.2 MB 279.6 kB/s eta 0:00:06
#    -------------- ------------------------- 0.8/2.2 MB 279.6 kB/s eta 0:00:06
#    ------------------- -------------------- 1.0/2.2 MB 266.3 kB/s eta 0:00:05
#    ------------------- -------------------- 1.0/2.2 MB 266.3 kB/s eta 0:00:05
#    ----------------------- ---------------- 1.3/2.2 MB 300.9 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.3/2.2 MB 300.9 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.3/2.2 MB 300.9 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.3/2.2 MB 300.9 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 299.6 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 299.6 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 299.6 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 299.6 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 299.6 kB/s eta 0:00:03
#    --------------------------------- ------ 1.8/2.2 MB 296.0 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 296.0 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 296.0 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 296.0 kB/s eta 0:00:02
#    -------------------------------------- - 2.1/2.2 MB 295.8 kB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 295.8 kB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 291.0 kB/s eta 0:00:00
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached pillow-11.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.8 kiwisolver-1.4.8 matplotlib-3.10.0 pillow-11.1.0 pyparsing-3.2.1 seaborn-0.13.2
# Requirement already satisfied: matplotlib in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from matplotlib) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\saurabh srivastava\onedrive\desktop\sem2\artificial_intel_450\claas_learning\env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
plt.figure(figsize= (4,2))

for col in num_cols:
    sns.histplot(data=df, x=col, kde=True)
    plt.show()

# %%
df.drop(df.fever==0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.drop(df.fever==0)
#
# File c:\Users\SAURABH SRIVASTAVA\OneDrive\Desktop\sem2\Artificial_intel_450\claas_learning\env\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\SAURABH SRIVASTAVA\OneDrive\Desktop\sem2\Artificial_intel_450\claas_learning\env\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\SAURABH SRIVASTAVA\OneDrive\Desktop\sem2\Artificial_intel_450\claas_learning\env\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\SAURABH SRIVASTAVA\OneDrive\Desktop\sem2\Artificial_intel_450\claas_learning\env\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: '[False, False, False, False, False, True, False, True, False, False, True, False, False, False, False, False, False, False, False, True, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False] not found in axis'
